# %%
import pandas as pd
import datadotworld as dw

# %%
uk_dataset = dw.load_dataset('datagov-uk/053a6529-6c8c-42ac-ae1e-455b2708e535')

# %%
uk_dataset.dataframes
# Out:
# LazyLoadedDict({'accident_2014_4': LazyLoadedValue(<pandas.DataFrame>), 'accident_2015_6': LazyLoadedValue(<pandas.DataFrame>), 'accident_2016_8': LazyLoadedValue(<pandas.DataFrame>), 'accident_2017_1': LazyLoadedValue(<pandas.DataFrame>), 'accident_2018_2': LazyLoadedValue(<pandas.DataFrame>), 'guidance_csv_11': LazyLoadedValue(<pandas.DataFrame>)})

# %%
results = dw.query('datagov-uk/053a6529-6c8c-42ac-ae1e-455b2708e535', 'SELECT * FROM accident_2014_4')

# %%
df1 = results.dataframe

# %%
results2 = dw.query('datagov-uk/053a6529-6c8c-42ac-ae1e-455b2708e535', 'SELECT * FROM accident_2015_6')

# %%
df2 = results2.dataframe

# %%
df_final = pd.concat([df1, df2])

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1179 entries, 0 to 555
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   reference_number     1179 non-null   object
#  1   grid_ref_easting     1179 non-null   int64
#  2   grid_ref_northing    1179 non-null   int64
#  3   number_of_vehicles   1179 non-null   int64
#  4   accident_date        1179 non-null   object
#  5   time_24hr            1179 non-null   int64
#  6   1st_road_class       1179 non-null   int64
#  7   1st_road_class_no    1179 non-null   object
#  8   road_surface         1179 non-null   int64
#  9   lighting_conditions  1179 non-null   int64
#  10  weather_conditions   1179 non-null   int64
#  11  local_authority      1179 non-null   object
#  12  casualty_class       1179 non-null   int64
#  13  casualty_severity    1179 non-null   int64
#  14  sex_of_casualty      1179 non-null   int64
# ...
