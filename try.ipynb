# %%
import pandas as pd
import datadotworld as dw

# %%
uk_dataset = dw.load_dataset('datagov-uk/053a6529-6c8c-42ac-ae1e-455b2708e535')

# %%
uk_dataset.dataframes
# Out:
# LazyLoadedDict({'accident_2014_4': LazyLoadedValue(<pandas.DataFrame>), 'accident_2015_6': LazyLoadedValue(<pandas.DataFrame>), 'accident_2016_8': LazyLoadedValue(<pandas.DataFrame>), 'accident_2017_1': LazyLoadedValue(<pandas.DataFrame>), 'accident_2018_2': LazyLoadedValue(<pandas.DataFrame>), 'guidance_csv_11': LazyLoadedValue(<pandas.DataFrame>)})

# %%
results = dw.query('datagov-uk/053a6529-6c8c-42ac-ae1e-455b2708e535', 'SELECT * FROM accident_2014_4')

# %%
results.dataframe
# Out:
#     reference_number  grid_ref_easting  grid_ref_northing  number_of_vehicles  \
# 0            11S0281            407491             428929                   1
# 1            11S1147            412912             429039                   1
# 2            11S1147            412912             429039                   1
# 3            11U0285            407179             424776                   2
# 4            11U0285            407179             424776                   2
# ..               ...               ...                ...                 ...
# 618          1CU0561            401834             419128                   4
# 619          1CU0561            401834             419128                   4
# 620          1CU0803            409343             424955                   1
# 621          1CV0997            405698             423377                   2
# 622          1CV0997            405698             423377                   2
#
#     accident_date  time_24hr  1st_road_class 1st_road_class_no  road_surface  \
# 0      2014-01-28        835               6                 U             2
# 1      2014-01-28       1745               6                 U             2
# 2      2014-01-28       1745               6                 U             2
# 3      2014-01-30        900               6                 U             2
# 4      2014-01-30        900               6                 U             2
# ..            ...        ...             ...               ...           ...
# 618    2014-12-30       1341               3               A58             2
# 619    2014-12-30       1341               3               A58             2
# 620    2014-12-30       1535               6                 U             2
# 621    2014-12-31       1800               6                 U             2
# 622    2014-12-31       1800               6                 U             2
#
#      lighting_conditions  weather_conditions local_authority  casualty_class  \
# 0                      1                   9      Calderdale               3
# 1                      4                   1      Calderdale               3
# 2                      4                   1      Calderdale               3
# 3                      1                   8      Calderdale               1
# 4                      1                   8      Calderdale               2
# ..                   ...                 ...             ...             ...
# 618                    1                   1      Calderdale               1
# 619                    1                   1      Calderdale               1
# 620                    1                   1      Calderdale               3
# 621                    4                   1      Calderdale               1
# 622                    4                   1      Calderdale               2
#
#      casualty_severity  sex_of_casualty  age_of_casualty  vehicle_number  \
# 0                    3                2                8               1
# 1                    3                2               15               1
# 2                    3                1               17               1
# 3                    3                2               29               2
# 4                    3                1                9               2
# ..                 ...              ...              ...             ...
# 618                  3                2               39               2
# 619                  3                1               25               3
# 620                  3                1                5               1
# 621                  2                2               34               1
# 622                  2                1               34               2
#
#      type_of_vehicle
# 0                  9
# 1                  9
# 2                  9
# 3                  9
# 4                  9
# ..               ...
# 618                9
# 619                9
# 620                9
# 621                9
# 622                9
#
# [623 rows x 18 columns]
